# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.metrics.pairwise import pairwise_kernels
import scipy
from sklearn import svm, linear_model
from sklearn.model_selection import GridSearchCV
import time
import pandas as pd

# %%
nameFile = open("features.txt")
nameList = []
for name in nameFile:
    name = name.strip()
    if name not in nameList:
        nameList.append(name)
    else:
        print(name, "is duplicate")
print(len(nameList))
    
df = pd.read_csv("cleaned_X_train.csv", names = nameList)
df.head(3)
# Out:
# 561
#    tBodyAcc-Mean-1  tBodyAcc-Mean-2  tBodyAcc-Mean-3  tBodyAcc-STD-1  \
# 0         0.043580        -0.005970        -0.035054       -0.995381
# 1         0.039480        -0.002131        -0.029067       -0.998348
# 2         0.039978        -0.005153        -0.022651       -0.995482
#
#    tBodyAcc-STD-2  tBodyAcc-STD-3  tBodyAcc-Mad-1  tBodyAcc-Mad-2  \
# 0       -0.988366       -0.937382       -0.995007       -0.988816
# 1       -0.982945       -0.971273       -0.998702       -0.983315
# 2       -0.977314       -0.984760       -0.996415       -0.975835
#
#    tBodyAcc-Mad-3  tBodyAcc-Max-1  ...  fBodyGyroJerkMag-MeanFreq-1  \
# 0       -0.953325       -0.794796  ...                    -0.012236
# 1       -0.974000       -0.802537  ...                     0.202804
# 2       -0.985973       -0.798477  ...                     0.440079
#
#    fBodyGyroJerkMag-Skewness-1  fBodyGyroJerkMag-Kurtosis-1  \
# 0                    -0.314848                    -0.713308
# 1                    -0.603199                    -0.860677
# 2                    -0.404427                    -0.761847
#
#    tBodyAcc-AngleWRTGravity-1  tBodyAccJerk-AngleWRTGravity-1  \
# 0                   -0.112754                        0.030400
# 1                    0.053477                       -0.007435
# 2                   -0.118559                        0.177899
#
#    tBodyGyro-AngleWRTGravity-1  tBodyGyroJerk-AngleWRTGravity-1  \
# 0                    -0.464761                        -0.018446
# 1                    -0.732626                         0.703511
# 2                     0.100699                         0.808529
#
#    tXAxisAcc-AngleWRTGravity-1  tYAxisAcc-AngleWRTGravity-1  \
# 0                    -0.841559                     0.179913
# 1                    -0.845092                     0.180261
# 2                    -0.849230                     0.180610
#
#    tZAxisAcc-AngleWRTGravity-1
# 0                    -0.051718
# 1                    -0.047436
# 2                    -0.042271
#
# [3 rows x 561 columns]

# %%
svc = svm.SVC(probability=False,  kernel="rbf", C=10, gamma=.05,verbose=10)
svc.fit(Xtr1, ytr8)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-cc5ba08b2b7a> in <module>
#       1 svc = svm.SVC(probability=False,  kernel="rbf", C=10, gamma=.05,verbose=10)
# ----> 2 svc.fit(Xtr1, ytr8)
#
# NameError: name 'Xtr1' is not defined
