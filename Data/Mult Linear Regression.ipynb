# %% [markdown]
# Multiple Linear Regression

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from sklearn import datasets, linear_model

# %%
Xtrain = pd.read_csv('cleaned_X_train.csv')
Xtest = pd.read_csv('cleaned_X_test.csv')
ytrain = pd.read_csv('y_train.csv')
ytest = pd.read_csv('y_test.csv')

# %%
print("Xtrain shape: ", Xtrain.shape)
print("ytrain shape: ", ytrain.shape)
print("Xtest shape: ", Xtest.shape)
print("ytest shape: ", ytest.shape)
# Out:
# Xtrain shape:  (7766, 561)
# ytrain shape:  (7766, 1)
# Xtest shape:  (3161, 561)
# ytest shape:  (3161, 1)

# %%
regr = linear_model.LinearRegression()
regr.fit(Xtrain,ytrain)
y_pred = regr.predict(Xtest)
lossm = np.linalg.norm(y_pred - ytest)**2
y_test = np.ravel(ytest)
ypred = np.ravel(y_pred)
acc = np.mean(ypred == y_test)
print('Accuaracy = {0:f}'.format(acc))
# Out:
# Accuaracy = 0.000000

# %%
plt.plot(ytest,'-')
plt.plot(y_pred,'-')
plt.grid(True)
plt.legend(['ytest','y_pred'])

# %% [markdown]
# Regularization
